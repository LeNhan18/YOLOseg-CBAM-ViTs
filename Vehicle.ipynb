# %% [markdown]
# <a href="https://colab.research.google.com/github/LeNhan18/SystemTrafficLaw/blob/Dev%2FAI/Vehicle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Kiểm tra GPU
# !nvidia-smi

import torch
print(f"\n✅ CUDA available: {torch.cuda.is_available()}")
print(f"✅ GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
print(f"✅ VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB" if torch.cuda.is_available() else "")
# Out:
# Sun Mar 29 19:40:34 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %% [markdown]
# ### Test Model đã huấn luyện

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2

# 1. Khai báo đường dẫn đến model tốt nhất của bạn
# Dựa vào các lần chạy trước, nó có thể nằm ở đây:
best_model_path = '/content/drive/MyDrive/yolo26_runs/vietnam_vehicle_v2_fixed/weights/best.pt'

# 2. Load model
model = YOLO(best_model_path)
print(f"Loaded best model from: {best_model_path}")

# 3. Chọn một ảnh để test từ tập test của bạn
# Thay đổi đường dẫn này đến một hình ảnh cụ thể trong tập test của bạn
test_image_path = '/content/drive/MyDrive/yolo_data/vietnam-vehicle/test/images/image-1335-_jpg.rf.859b813b41bf4d13774844391696230f.jpg'

# Kiểm tra xem ảnh có tồn tại không
import os
if not os.path.exists(test_image_path):
    print(f"⚠️ Lỗi: Không tìm thấy ảnh tại đường dẫn: {test_image_path}")
    print("Vui lòng cập nhật 'test_image_path' đến một đường dẫn ảnh hợp lệ.")
else:
    # 4. Chạy inference trên ảnh test
    results = model(test_image_path)

    # 5. Hiển thị kết quả
    # results[0].plot() sẽ trả về một numpy array (B, G, R)
    # Matplotlib cần ảnh RGB, nên chúng ta cần chuyển đổi.
    result_image_bgr = results[0].plot() # Đây là ảnh dạng BGR (OpenCV format)
    result_image_rgb = cv2.cvtColor(result_image_bgr, cv2.COLOR_BGR2RGB)

    plt.figure(figsize=(12, 9))
    plt.imshow(result_image_rgb)
    plt.axis('off')
    plt.title('Prediction Results')
    plt.show()

    # In ra thông tin chi tiết về các đối tượng được phát hiện
    print("\nDetected objects:")
    for r in results:
        for c in r.boxes.cls:
            print(f"  - Class: {model.names[int(c)]}")

# %%
                                            # Cài đặt Ultralytics YOLOv8
# %pip install ultralytics -q

from ultralytics import YOLO
import ultralytics
ultralytics.checks()
print(" Ultralytics YOLOv8 đã sẵn sàng!")
# Out:
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 43.6/112.6 GB disk)
#  Ultralytics YOLOv8 đã sẵn sàng!

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
print(" Google Drive đã kết nối!")
# Out:
# Mounted at /content/drive
#  Google Drive đã kết nối!

# %%
import zipfile, shutil

# ====================================================
# 🔧 CẤU HÌNH – Chỉnh đường dẫn cho phù hợp với bạn
# ====================================================
ZIP_PATH = '/content/drive/MyDrive/Colab Notebooks/vietnam-vehicle.zip'
EXTRACT_DIR = '/content/vietnam-vehicle'
# ====================================================

# Giải nén dataset
if not os.path.exists(EXTRACT_DIR):
    print(f" Đang giải nén {ZIP_PATH}...")
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall(EXTRACT_DIR)
    print(" Giải nén xong!")
else:
    print(" Dataset đã tồn tại, bỏ qua giải nén.")

# Kiểm tra cấu trúc thư mục
print("\n Cấu trúc dataset:")
for root, dirs, files in os.walk(EXTRACT_DIR):
    level = root.replace(EXTRACT_DIR, '').count(os.sep)
    indent = ' ' * 2 * level
    print(f'{indent}{os.path.basename(root)}/')
    if level < 3:
        subindent = ' ' * 2 * (level + 1)
        for f in files[:5]:
            print(f'{subindent}{f}')
        if len(files) > 5:
            print(f'{subindent}... ({len(files)} files total)')
# Out:
#  Đang giải nén /content/drive/MyDrive/Colab Notebooks/vietnam-vehicle.zip...
#  Giải nén xong!
#
#  Cấu trúc dataset:
# vietnam-vehicle/
#   README.roboflow.txt
#   data.yaml
#   README.dataset.txt
#   train/
#     images/
#       image-526-_jpg.rf.9866c856a4cf6d064a49c48b9b93efa1.jpg
#       image-1797-_jpg.rf.d9ec662acfb5e7adf412e3ba6fb3b32e.jpg
#       image-300-_jpg.rf.999fd839e9f871f6200a648b5ae90acf.jpg
#       image-2013-_jpg.rf.cdc5108b2d198e6266068f754f9d3146.jpg
#       image-1423-_jpg.rf.1aa214ea575f7c6c8befafd5e310cd42.jpg
#       ... (4179 files total)
#     labels/
#       image-1247-_jpg.rf.53b6612330a52861089e68da663207d2.txt
#       image-171-_jpg.rf.727573627d50ecbbc91a4029a43503a2.txt
#       image-181-_jpg.rf.53508c1b0cd0d59e400c7f1b71d6bcf7.txt
#       image-1558-_jpg.rf.f20bd7f9dbc61159749f08b04bfa9153.txt
#       image-2024-_jpg.rf.61966e6aea02991fe15bba7358e915d9.txt
#       ... (4179 files total)
#   test/
#     images/
# ...

# %%
# Tạo thư mục chứa trên Drive (nếu chưa có)
# !mkdir -p /content/drive/MyDrive/yolo_data

# Di chuyển (hoặc copy) thư mục dataset sang Drive
# Sử dụng !cp -r nếu muốn copy, !mv nếu muốn di chuyển hẳn
# !cp -r /content/vietnam-vehicle /content/drive/MyDrive/yolo_data/

# %%
import yaml, glob
from pathlib import Path

# Auto-detect cấu trúc dataset
dataset_root = EXTRACT_DIR

# Tìm thư mục images/train và images/val
train_img_dirs = glob.glob(f'{dataset_root}/**/images/train', recursive=True)
val_img_dirs   = glob.glob(f'{dataset_root}/**/images/val', recursive=True)
label_dirs     = glob.glob(f'{dataset_root}/**/labels/train', recursive=True)

# Hiển thị các thư mục tìm được
print(" Train images dirs:", train_img_dirs)
print(" Val images dirs:",   val_img_dirs)
print(" Label dirs:",        label_dirs)

# Kiểm tra xem có file yaml sẵn không
existing_yamls = glob.glob(f'{dataset_root}/**/*.yaml', recursive=True)
print("\n YAML files tìm được:", existing_yamls)
# Out:
#  Train images dirs: []
#  Val images dirs: []
#  Label dirs: []
#
#  YAML files tìm được: ['/content/vietnam-vehicle/data.yaml']

# %%
# ====================================================
# 🔧 Nếu chưa có yaml, tạo thủ công ở đây
# Điền đúng tên classes của bộ dữ liệu vietnam-vehicle
# ====================================================

# Tự động đọc classes từ label files nếu có
Yaml_path ="/content/drive/MyDrive/yolo_data/vietnam-vehicle/data.yaml"
def get_classes_from_labels(label_dir):
    """Đọc tất cả class IDs từ label files"""
    class_ids = set()
    for lf in glob.glob(f'{label_dir}/*.txt'):
        with open(lf) as f:
            for line in f:
                parts = line.strip().split()
                if parts:
                    class_ids.add(int(parts[0]))
    return sorted(class_ids)

# Mặc định classes cho Vietnam Vehicle (chỉnh nếu cần)
DEFAULT_CLASSES = {
    0: 'motorbike',
    1: 'car',
    2: 'bus',
    3: 'truck',
    4: 'bicycle'
}

# Dùng yaml có sẵn nếu tìm được, hoặc tạo mới
if existing_yamls:
    DATA_YAML = existing_yamls[0]
    print(f" Dùng YAML có sẵn: {DATA_YAML}")
    with open(DATA_YAML) as f:
        print(yaml.safe_load(f))
else:
    # Xác định đường dẫn train/val
    if train_img_dirs:
        train_path = train_img_dirs[0]
        val_path   = val_img_dirs[0] if val_img_dirs else train_img_dirs[0].replace('train', 'val')
        root_path  = str(Path(train_path).parents[1])
    else:
        # Fallback: dataset flat
        root_path  = dataset_root
        train_path = f'{dataset_root}/train/images'
        val_path   = f'{dataset_root}/valid/images'

    data_config = {
        'path':  root_path,
        'train': 'images/train',
        'val':   'images/val',
        'nc':    len(DEFAULT_CLASSES),
        'names': DEFAULT_CLASSES
    }

    DATA_YAML = f'{dataset_root}/data.yaml'
    with open(DATA_YAML, 'w') as f:
        yaml.dump(data_config, f, default_flow_style=False, allow_unicode=True)

    print(f" Đã tạo: {DATA_YAML}")
    print(data_config)

print(f"\n📄 DATA_YAML = '{DATA_YAML}'")
# Out:
#  Dùng YAML có sẵn: /content/vietnam-vehicle/data.yaml
# {'train': '../train/images', 'val': '../valid/images', 'test': '../test/images', 'nc': 4, 'names': ['0', '1', '2', '3'], 'roboflow': {'workspace': 'vehicle-xxgod', 'project': 'vietnam-vehicle-detection', 'version': 2, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/vehicle-xxgod/vietnam-vehicle-detection/dataset/2'}}
#
# 📄 DATA_YAML = '/content/vietnam-vehicle/data.yaml'

# %%
import yaml

# Đọc yaml gốc
Yaml_path ="/content/drive/MyDrive/yolo_data/vietnam-vehicle/data.yaml"
EX_DIR = "/content/drive/MyDrive/yolo_data/vietnam-vehicle/"
with open(Yaml_path, 'r') as f:
    cfg = yaml.safe_load(f)

print(" YAML gốc:")
print(cfg)

# ==================================================
# 🔧 Đặt tên class thực tế theo yêu cầu:
# 0: car, 1: motocycle, 2: truck, 3: bus
# ==================================================
CLASS_NAMES = {
    0: 'car',        # class 0
    1: 'motocycle',  # class 1
    2: 'truck',      # class 2
    3: 'bus'         # class 3
}
# ==================================================

# Cập nhật yaml: fix path tuyệt đối + tên class
cfg_fixed = {
    'path':  EX_DIR,
    'train': 'train/images',
    'val':   'valid/images',
    'test':  'test/images',
    'nc':    4,
    'names': CLASS_NAMES
}

FIXED_YAML = f'{EX_DIR}/data_fixed.yaml'
with open(FIXED_YAML, 'w') as f:
    yaml.dump(cfg_fixed, f, default_flow_style=False, allow_unicode=True)

print("\n YAML đã sửa:")
print(cfg_fixed)
print(f"\n Dùng: '{FIXED_YAML}'")
# Out:
#  YAML gốc:
# {'train': '../train/images', 'val': '../valid/images', 'test': '../test/images', 'nc': 4, 'names': ['0', '1', '2', '3'], 'roboflow': {'workspace': 'vehicle-xxgod', 'project': 'vietnam-vehicle-detection', 'version': 2, 'license': 'CC BY 4.0', 'url': 'https://universe.roboflow.com/vehicle-xxgod/vietnam-vehicle-detection/dataset/2'}}
#
#  YAML đã sửa:
# {'path': '/content/drive/MyDrive/yolo_data/vietnam-vehicle/', 'train': 'train/images', 'val': 'valid/images', 'test': 'test/images', 'nc': 4, 'names': {0: 'car', 1: 'motocycle', 2: 'truck', 3: 'bus'}}
#
#  Dùng: '/content/drive/MyDrive/yolo_data/vietnam-vehicle//data_fixed.yaml'

# %%
import glob, collections
from pathlib import Path

# Đếm số lượng mỗi class trong train set
label_files = glob.glob(f'{EX_DIR}/train/labels/*.txt')
counter = collections.Counter()
for lf in label_files:
    with open(lf) as f:
        for line in f:
            parts = line.strip().split()
            if parts:
                counter[int(parts[0])] += 1

print(" Phân phối class trong Train Set:")
for cls_id, count in sorted(counter.items()):
    cls_name = CLASS_NAMES.get(cls_id, f'class_{cls_id}')
    bar = '█' * (count // 200)
    print(f"  [{cls_id}] {cls_name:12s}: {count:6d}  {bar}")

total = sum(counter.values())
print(f"\n  Total bounding boxes: {total}")
print(f"  Total label files:    {len(label_files)}")

# Cảnh báo mất cân bằng class
if counter:
    max_c = max(counter.values())
    min_c = min(counter.values())
    ratio = max_c / max(min_c, 1)
    if ratio > 5:
        print(f"\n  Mất cân bằng class! Tỉ lệ max/min = {ratio:.1f}x")
        print("   → Sẽ dùng cls_weights trong training để bù.")
    else:
        print(f"\n Class balance OK (ratio = {ratio:.1f}x)")
# Out:
#  Phân phối class trong Train Set:
#   [0] car         :  13923  █████████████████████████████████████████████████████████████████████
#   [1] motocycle   :  17046  █████████████████████████████████████████████████████████████████████████████████████
#   [2] truck       :   1130  █████
#   [3] bus         :    361  █
#
#   Total bounding boxes: 32460
#   Total label files:    4179
#
#   Mất cân bằng class! Tỉ lệ max/min = 47.2x
#    → Sẽ dùng cls_weights trong training để bù.

# %%
import os, glob, shutil, random
from pathlib import Path

train_img_dir = f"{EXTRACT_DIR}/train/images"
train_lbl_dir = f"{EXTRACT_DIR}/train/labels"

# class repeat factors
# 0:car, 1:motocycle, 2:truck, 3:bus
repeat_map = {
    2: 4,   # truck
    3: 12   # bus
}

img_exts = [".jpg", ".jpeg", ".png", ".webp"]
label_files = glob.glob(f"{train_lbl_dir}/*.txt")

def find_image(stem):
    for ext in img_exts:
        p = Path(train_img_dir) / f"{stem}{ext}"
        if p.exists():
            return p
    return None

created = 0
for lf in label_files:
    stem = Path(lf).stem
    with open(lf, "r", encoding="utf-8") as f:
        lines = [x.strip() for x in f if x.strip()]
    if not lines:
        continue

    classes = set(int(x.split()[0]) for x in lines)
    max_repeat = max([repeat_map.get(c, 1) for c in classes])

    if max_repeat <= 1:
        continue

    src_img = find_image(stem)
    if src_img is None:
        continue

    for r in range(1, max_repeat):
        new_stem = f"{stem}_rep{r}"
        new_lbl = Path(train_lbl_dir) / f"{new_stem}.txt"
        new_img = Path(train_img_dir) / f"{new_stem}{src_img.suffix}"

        shutil.copy2(lf, new_lbl)
        shutil.copy2(src_img, new_img)
        created += 1

print(f"Done. Created {created} oversampled pairs.")
# Out:
# Done. Created 5942 oversampled pairs.

# %%
# ==================================================
# 🔧 HYPERPARAMETER TỐI ƯU CHO YOLO26
# ==================================================

MODEL_SIZE = 'yolo26m'   # Đổi sang 'yolo26l' nếu có A100

TRAIN_CONFIG = {
    # === Dataset ===
    'data':     FIXED_YAML,
    'imgsz':    640,          # 640 là chuẩn, tăng 1280 cho vật thể nhỏ

    # === Training schedule ===
    'epochs':   150,          # 150 epochs cho 4700 ảnh là hợp lý
    'batch':    16,           # Giảm 8 nếu gặp CUDA out of memory
    'device':   0,

    # === Optimizer – YOLO26 dùng MuSGD mặc định ===
    # Không cần chỉ định optimizer vì YOLO26 tự chọn MuSGD
    'lr0':      0.01,         # LR khởi đầu
    'lrf':      0.01,         # LR cuối = lr0 * lrf
    'momentum': 0.937,
    'weight_decay': 0.0005,
    'warmup_epochs': 3.0,
    'warmup_momentum': 0.8,
    'cos_lr':   True,         # Cosine annealing scheduler

    # === Augmentation mạnh để tăng mAP ===
    'hsv_h':     0.015,
    'hsv_s':     0.7,
    'hsv_v':     0.4,
    'degrees':   5.0,         # Xe thường không nghiêng nhiều
    'translate': 0.1,
    'scale':     0.5,
    'shear':     2.0,
    'perspective': 0.0001,
    'flipud':    0.0,         # Xe không lộn ngược
    'fliplr':    0.5,
    'mosaic':    1.0,         #  Quan trọng – tăng mAP đáng kể
    'mixup':     0.15,
    'copy_paste': 0.1,
    'erasing':   0.4,

    # === Regularization ===
    'label_smoothing': 0.1,
    'dropout':   0.0,

    # === Inference ===
    'conf':      0.001,       # Ngưỡng thấp khi eval để tính đúng mAP
    'iou':       0.7,
    'nms':       False,       # YOLO26 là NMS-free!

    # === Logging & Saving ===
    'patience':  30,
    'save':      True,
    'save_period': 10,
    'cache':     True,        # Cache ảnh vào RAM – train nhanh hơn ~30%
    'workers':   4,
    'plots':     True,
    'val':       True,
    'pretrained': True,       # Luôn bật – transfer learning từ COCO
    'multi_scale': False,     # Bật True nếu muốn detect xe nhỏ & xa
    'overlap_mask': True,

    # === Output – lưu vào GDrive để không mất khi Colab reset ===
    'project':  '/content/drive/MyDrive/yolo26_runs',
    'name':     'vietnam_vehicle_v1',
    'exist_ok': True,
}
# ==================================================

print("  Cấu hình training YOLO26:")
for k, v in TRAIN_CONFIG.items():
    print(f"   {k:20s}: {v}")
# Out:
#   Cấu hình training YOLO26:
#    data                : /content/vietnam-vehicle/data_fixed.yaml
#    imgsz               : 640
#    epochs              : 150
#    batch               : 16
#    device              : 0
#    lr0                 : 0.01
#    lrf                 : 0.01
#    momentum            : 0.937
#    weight_decay        : 0.0005
#    warmup_epochs       : 3.0
#    warmup_momentum     : 0.8
#    cos_lr              : True
#    hsv_h               : 0.015
#    hsv_s               : 0.7
#    hsv_v               : 0.4
#    degrees             : 5.0
#    translate           : 0.1
#    scale               : 0.5
#    shear               : 2.0
#    perspective         : 0.0001
#    flipud              : 0.0
#    fliplr              : 0.5
#    mosaic              : 1.0
#    mixup               : 0.15
#    copy_paste          : 0.1
#    erasing             : 0.4
#    label_smoothing     : 0.1
#    dropout             : 0.0
#    conf                : 0.001
# ...

# %%
from ultralytics import YOLO
import time

# Load YOLO26 pretrained trên COCO
model = YOLO(f'{MODEL_SIZE}.pt')
print(f" Loaded: {MODEL_SIZE}.pt  (pretrained on COCO)")
print(f" Bắt đầu training...\n")

t0 = time.time()
results = model.train(**TRAIN_CONFIG)
elapsed = time.time() - t0

print(f"\n{'='*50}")
print(f" Training xong! Thời gian: {elapsed/3600:.2f} giờ")
print(f" Lưu tại: {results.save_dir}")
# Out:
# ...
#  Loaded: yolo26m.pt  (pretrained on COCO)
#  Bắt đầu training...
#
# WARNING ⚠️ 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.4.29 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ### Debugging và Tiếp tục Training
#
# Nếu training bị dừng đột ngột, có thể là do:
# - **Mất kết nối Colab:** Colab có thể tự ngắt kết nối nếu không tương tác trong một thời gian hoặc khi tài nguyên GPU được cấp phát lại.
# - **Lỗi bộ nhớ (CUDA out of memory):** Đặc biệt nếu bạn tăng `batch` size hoặc `imgsz` quá cao.
# - **Lỗi trong quá trình xử lý dữ liệu:** Có thể có ảnh hoặc label bị lỗi.
# - **Patience:** Mặc dù không likely ở epoch 16 với patience là 30, nhưng nếu không có sự cải thiện nào về metric trong 30 epoch liên tiếp, training sẽ dừng sớm.
#
# Bạn nên kiểm tra log output của cell training trước đó để tìm bất kỳ thông báo lỗi nào.
#
# Để tiếp tục training từ checkpoint cuối cùng, bạn có thể sử dụng tùy chọn `resume=True` của Ultralytics. Đầu tiên, hãy kiểm tra xem có những bản chạy nào đã được lưu trong thư mục `project` của bạn.

# %%
model.train(
    data= '/content/drive/MyDrive/yolo_data/vietnam-vehicle/data_fixed.yaml',
    epochs=150,
    imgsz=640,
    project='/content/drive/MyDrive/yolo26_runs',
    name='vietnam_vehicle_v2',
    exist_ok=False,
    resume=False
)
# Out:
# Ultralytics 8.4.30 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from ultralytics import YOLO

# 1. Khai báo đường dẫn chính xác tới file last.pt của bạn.
# Dựa vào code và ảnh của bạn, đường dẫn có thể sẽ như thế này:
checkpoint_path = '/content/drive/MyDrive/yolo26_runs/vietnam_vehicle_v2/weights/last.pt'

# 2. Load model từ checkpoint cuối cùng
model = YOLO(checkpoint_path)

# %%
model.train(
    data= '/content/drive/MyDrive/yolo_data/vietnam-vehicle/data_fixed.yaml',
    epochs=40,
    imgsz=640,
    project='/content/drive/MyDrive/yolo26_runs',
    name='vietnam_vehicle_v3', # Đổi tên để tiếp tục cùng một lần chạy
    exist_ok=True,           # Cho phép ghi đè vào thư mục đã tồn tại
    resume=True              # Tiếp tục huấn luyện từ checkpoint cuối cùng
)
# Out:
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5535/1067756747.py in <cell line: 0>()
# ----> 1 model.train(
#       2     data= '/content/drive/MyDrive/yolo_data/vietnam-vehicle/data_fixed.yaml',
#       3     epochs=40,
#       4     imgsz=640,
#       5     project='/content/drive/MyDrive/yolo26_runs',
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     781                     args["resume"] = False
#     782
# --> 783         self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     784         if not args.get("resume"):  # manually set model only if not resuming
#     785             self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#
# ...

# %%
from ultralytics import YOLO

# 1. Khai báo đường dẫn chính xác tới file last.pt của bạn.
# Dựa vào code và ảnh của bạn, đường dẫn có thể sẽ như thế này:
checkpoint_path = '/content/drive/MyDrive/vietnam_vehicle_v2.1/weights/last.pt'

# 2. Load model từ checkpoint cuối cùng
model = YOLO(checkpoint_path)

# %%
import yaml

yaml_path = '/content/drive/MyDrive/yolo_data/vietnam-vehicle/data_fixed.yaml'

# Load the current YAML content
with open(yaml_path, 'r') as file:
    yaml_content = yaml.safe_load(file)

# Correct the 'path' entry
yaml_content['path'] = '/content/drive/MyDrive/yolo_data/vietnam-vehicle/'

# Save the updated YAML content back to the file
with open(yaml_path, 'w') as file:
    yaml.dump(yaml_content, file, indent=2)

print("Đã cập nhật file data_fixed.yaml với đường dẫn chính xác:")
print(yaml.dump(yaml_content, indent=2))
# Out:
# Đã cập nhật file data_fixed.yaml với đường dẫn chính xác:
# names:
#   0: car
#   1: motocycle
#   2: truck
#   3: bus
# nc: 4
# path: /content/drive/MyDrive/yolo_data/vietnam-vehicle/
# test: test/images
# train: train/images
# val: valid/images

# %%
from ultralytics import YOLO

# Load model bạn đã có (last.pt)
# Chạy train
model.train(
    data='/content/drive/MyDrive/yolo_data/vietnam-vehicle/data_fixed.yaml',
    epochs=100,
    imgsz=640,
    project='/content/drive/MyDrive/yolo26_runs',
    name='vietnam_vehicle_v2_fixed',
    exist_ok=True,           # Cho phép ghi đè vào thư mục đã tồn tại
    resume=True
)
# Out:
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
